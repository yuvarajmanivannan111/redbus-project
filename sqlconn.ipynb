# %%
#importing libraries
import pandas as pd
import mysql.connector
import numpy as np

# %%
# csv to dataframe
df_buses_1=pd.read_csv("df_buses_1.csv")
df_buses_2=pd.read_csv("df_buses_2.csv")
df_buses_3=pd.read_csv("df_buses_3.csv")
df_buses_4=pd.read_csv("df_buses_4.csv")
df_buses_5=pd.read_csv("df_buses_R.csv")
df_buses_6=pd.read_csv("df_buses_SB.csv")
df_buses_7=pd.read_csv("df_buses_H.csv")
df_buses_8=pd.read_csv("df_buses_AS.csv")
df_buses_9=pd.read_csv("df_buses_9.csv")
df_buses_10=pd.read_csv("df_buses_10.csv")

Final_df=pd.concat([df_buses_1,df_buses_2,df_buses_3,df_buses_4,df_buses_5,df_buses_6,
                    df_buses_7,df_buses_8,df_buses_9,df_buses_10],ignore_index=True)
Final_df
# Out:
#                                                Bus_name  \
# 0                                   KSRTC (Kerala) - 97
# 1                                  KSRTC (Kerala) - 171
# 2                                  KSRTC (Kerala) - 553
# 3                                   KSRTC (Kerala) - 51
# 4                                  KSRTC (Kerala) - 789
# ...                                                 ...
# 1854              WBTC (CTC) Habra-Midnapur - 194|06:25
# 1855              WBTC (CTC) Habra-Midnapur - 194|07:00
# 1856       SBSTC-HABRA - HALDIA - 06:50 (HALDIA) - 1509
# 1857                                Santosh Bus Service
# 1858  SBSTC-HABRA - MIDNAPUR - 06:20 (MID DEPOT) - 1398
#
#                                       Bus_type Start_time End_time  \
# 0            Swift Deluxe Non AC Air Bus (2+2)      16:02    00:50
# 1            Swift Deluxe Non AC Air Bus (2+2)      16:16    01:20
# 2     Super Deluxe Non AC Seater Air Bus (2+2)      16:45    01:25
# ...

# %% [markdown]
# # Data cleaning

# %%
# data about the data
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1859 entries, 0 to 1858
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1804 non-null   object
#  1   Bus_type         1801 non-null   object
#  2   Start_time       1804 non-null   object
#  3   End_time         1804 non-null   object
#  4   Total_duration   1804 non-null   object
#  5   Price            1804 non-null   object
#  6   Seats_Available  1801 non-null   object
#  7   Ratings          1804 non-null   object
#  8   Route_link       1859 non-null   object
#  9   Route_name       1859 non-null   object
# dtypes: object(10)
# memory usage: 145.4+ KB

# %%
#convert prices to numeric
Final_df["Price"]=Final_df["Price"].str.replace("INR","")
Final_df["Price"]=Final_df["Price"].astype(float)
Final_df["Price"].fillna(0)
# Out:
# 0       567.0
# 1       640.0
# 2       640.0
# 3       640.0
# 4       473.0
#         ...
# 1854     73.0
# 1855     73.0
# 1856    142.0
# 1857    360.0
# 1858    143.0
# Name: Price, Length: 1859, dtype: float64

# %%
#convert Ratings to numeric
Final_df["Ratings"]=Final_df["Ratings"].str.replace("New","")
Final_df["Ratings"]=Final_df["Ratings"].str.strip()
Final_df["Ratings"]=Final_df["Ratings"].str.split().str[0]
Final_df["Ratings"] = pd.to_numeric(Final_df["Ratings"], errors='coerce')
Final_df["Ratings"].fillna(0,inplace=True)
# Out:
# C:\Users\yuvanelson\AppData\Local\Temp\ipykernel_18548\2577861265.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Final_df["Ratings"].fillna(0,inplace=True)

# %%
# info after the data type change
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1859 entries, 0 to 1858
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         1804 non-null   object
#  1   Bus_type         1801 non-null   object
#  2   Start_time       1804 non-null   object
#  3   End_time         1804 non-null   object
#  4   Total_duration   1804 non-null   object
#  5   Price            1804 non-null   float64
#  6   Seats_Available  1801 non-null   object
#  7   Ratings          1859 non-null   float64
#  8   Route_link       1859 non-null   object
#  9   Route_name       1859 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 145.4+ KB

# %%
Final_df = Final_df[Final_df["Price"] <= 7000]

# %%
# replacing the nan value
Final_df = Final_df.replace({np.nan: None})

# %%
# change dataframe to csv
path=r"C:/Users/yuvanelson/Documents/scraping/bus/Final_busdetails_df.csv"
Final_df.to_csv(path,index=False)

# %% [markdown]
# # Create a mysql database

# %%
my_cursor.execute("DROP database RED_BUS_DETAILS")

# %%
#sql connection
conn=mysql.connector.connect(
 host="localhost",
 user="root",
 password="",
)
my_cursor = conn.cursor()
# my_cursor.execute("CREATE DATABASE IF NOT EXISTS RED_BUS_DETAILS")

# %%
# Table Creation
my_cursor.execute('''CREATE TABLE  IF NOT EXISTS RED_BUS_DETAILS.bus_details(ID INT AUTO_INCREMENT PRIMARY KEY,Bus_name VARCHAR(255) NOT NULL,Bus_type VARCHAR(255) NOT NULL,Start_time VARCHAR(255) NOT NULL,End_time VARCHAR(255) NOT NULL,Total_duration VARCHAR(255) NOT NULL,Price FLOAT NULL,Seats_Available VARCHAR(255) NOT NULL,Ratings Float NULL,Route_link VARCHAR(255) NULL,Route_name VARCHAR(255) NULL)''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
# SQL query to insert data into bus_details table
insert_query = '''INSERT INTO RED_BUS_DETAILS.bus_details(
                    Bus_name,
                    Bus_type,
                    Start_time,
                    End_time,
                    Total_duration,
                    Price,
                    Seats_Available,
                    Ratings,
                    Route_link,
                    Route_name)
                  VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
data = Final_df.values.tolist()

my_cursor.executemany(insert_query, data)

conn.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully

# %%
my_cursor.execute("SELECT * FROM RED_BUS_DETAILS.bus_details")



out=my_cursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in my_cursor.description],  tablefmt='psql'))
# Out:
# +------+-----------------------------------------------------------------+--------------------------------------------------+--------------+------------+------------------+---------+--------------------+-----------+---------------------------------------------------------------------------+------------------------------------------------+
# |   ID | Bus_name                                                        | Bus_type                                         | Start_time   | End_time   | Total_duration   |   Price | Seats_Available    |   Ratings | Route_link                                                                | Route_name                                     |
# ...

# %%
my_cursor.execute("SELECT * FROM RED_BUS_DETAILS.bus_details ")



out=my_cursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in my_cursor.description],  tablefmt='psql'))
# Out:
# +------+-----------------------------------------------------------------+--------------------------------------------------+--------------+------------+------------------+---------+--------------------+-----------+---------------------------------------------------------------------------+------------------------------------------------+
# |   ID | Bus_name                                                        | Bus_type                                         | Start_time   | End_time   | Total_duration   |   Price | Seats_Available    |   Ratings | Route_link                                                                | Route_name                                     |
# ...

# %%
import streamlit as slt
from streamlit_option_menu import option_menu
import plotly.express as px

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB 1.4 MB/s eta 0:00:09
#      ---------------------------------------- 0.1/11.9 MB 1.1 MB/s eta 0:00:12
#       --------------------------------------- 0.2/11.9 MB 1.7 MB/s eta 0:00:07
#       --------------------------------------- 0.3/11.9 MB 1.5 MB/s eta 0:00:08
#      - -------------------------------------- 0.6/11.9 MB 2.3 MB/s eta 0:00:05
#      -- ------------------------------------- 0.8/11.9 MB 2.7 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.4/11.9 MB 3.9 MB/s eta 0:00:03
#      ------- -------------------------------- 2.2/11.9 MB 5.7 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.0/11.9 MB 6.9 MB/s eta 0:00:02
#      ------------ --------------------------- 3.7/11.9 MB 7.7 MB/s eta 0:00:02
#      ------------- -------------------------- 4.0/11.9 MB 7.6 MB/s eta 0:00:02
# ...
